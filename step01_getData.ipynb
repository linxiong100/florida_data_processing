# %%
# get data

# %%
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
gdf = gpd.read_file('../data/enp_geo.gpkg')

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
gdf.total_bounds
# Out:
# array([-81.52084105,  24.85675453, -80.38847621,  25.89239593])

# %%
bounds = [-81.6, 24.8, -80.3, 25.9]
# go nasa earth data search and subset.

# %%
# gedi granules 202 GEDI L2A Elevation and Height Metrics Data Global Footprint Level V002

# %%
# alt08 granues 230
# Some granules did not produce any output. 13 granules reported "Granule contained no data within the spatial and/or temporal subset constraints".
# https://n5eil02u.ecs.nsidc.org/esir/5000005586674.html

# %%
# !ls ../data/earthdata/
# Out:
# 5000005586674.zip
